# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb


x=[.33, 4.51, 4.64, 4.36, 1.85, 3.31, 0.493, 2.88]
y=[3.3, .554, .470, .642, 1.78, 1.21, 2.47, 1.47]

c=[x[i]*y[i] 
   for i in range(len(x))]

d=[x[i]*x[i] 
   for i in range(len(x))]

e=[y[i]*y[i] 
   for i in range(len(x))]
print(c)
 
plt.scatter(x=x, y = y)
plt.scatter(x, y)
plt.show()
# Out:
# [1.089, 2.49854, 2.1807999999999996, 2.7991200000000003, 3.293, 4.0051, 1.21771, 4.2336]
