# %%
import pandas as pd

# Cargar el archivo CSV indicando que la fila 2 contiene los encabezados
data = pd.read_csv('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\electronica\\Transistores\\1Transis.csv', header=1)
print(data.columns)
# Out:
# Index(['V_BE', 'V_RB', 'I_B', 'V_BE1', 'V_RB1', 'I_B1', 'V_BE2', 'V_RB2',
#        'I_B2', 'Unnamed: 9'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Aquí defines tu patrón de entrada como un string
csv_data = """
V_BE,V_RB,I_B,V_BE1,V_RB1,I_B1,V_BE2,V_RB2,I_B2,
0.71,9.25,0.0000925,0.7,9.29,0.0000929,0.7,9.28,0.0000928,
0.709,8.93,0.0000893,0.703,9.03,0.0000903,0.7,9,0.00009,
0.707,8.1,0.000081,0.704,8.55,0.0000855,0.7,8.51,0.0000851,
0.7,7.08,0.0000708,0.703,7.98,0.0000798,0.7,7.99,0.0000799,
0.692,6.37,0.0000637,0.702,7.47,0.0000747,0.699,7.47,0.0000747,
0.685,5.77,0.0000577,0.702,7.02,0.0000702,0.699,6.96,0.0000696,
0.674,4.91,0.0000491,0.701,6.51,0.0000651,0.698,6.51,0.0000651,
0.67,4.67,0.0000467,0.699,6,0.00006,0.698,6.03,0.0000603,
0.666,4.11,0.0000411,0.694,5.56,0.0000556,0.697,5.57,0.0000557,
0.663,3.75,0.0000375,0.686,5.01,0.0000501,0.694,5.08,0.0000508,
0.66,3.45,0.0000345,0.679,4.52,0.0000452,0.686,4.56,0.0000456,
0.658,3.14,0.0000314,0.672,3.99,0.0000399,0.679,4.08,0.0000408,
0.657,2.81,0.0000281,0.666,3.49,0.0000349,0.671,3.5,0.000035,
0.651,2.48,0.0000248,0.661,3.03,0.0000303,0.664,2.96,0.0000296,
0.648,2.07,0.0000207,0.656,2.55,0.0000255,0.658,2.5,0.000025,
0.643,1.43,0.0000143,0.65,1.98,0.0000198,0.651,1.99,0.0000199,
0.637,1.04,0.0000104,0.644,1.5,0.000015,0.644,1.47,0.0000147,
0.635,0.83,0.0000083,0.637,1.03,0.0000103,0.639,1.09,0.0000109,
0.627,0.6,0.000006,0.622,0.45,0.0000045,0.623,0.53,0.0000053,
0.62,0.42,0.0000042,0.543,0.02,0.0000002,0.605,0.23,0.0000023,
0.615,0.208,0.00000208,0.615,0.29,0.0000029,0.556,0.04,0.0000004,
0.562,0.04,0.0000004,0.46,0.001,0.00000001,0.422,0.001,0.00000001,
0.49,0.02,0.0000002,0.049,0,0,0.566,0.05,0.0000005,
0.55,0.03,0.0000003,,,0,0.081,0,0,

"""

# Crea un archivo temporal con los datos
with open('datos_temporales.csv', 'w') as file:
    file.write(csv_data)

# Lee el archivo CSV
data = pd.read_csv('datos_temporales.csv',na_values=['NA', 'NaN', 'N/A'])

# Graficar el gráfico de dispersión para conjuntos de datos específicos
plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)

# Columnas de interés para el gráfico de dispersión
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

# Colores y marcadores para cada conjunto de datos
colors = ['red', 'blue', 'green']
markers = ['o', '^', 's']

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]

    # Graficar el gráfico de dispersión con colores y marcadores diferentes para cada conjunto de datos
    plt.scatter(x, y, color=colors[i], marker=markers[i], label=f'Datos {i+1}')

# Etiquetas y título
plt.xlabel('Etiqueta eje X')
plt.ylabel('Etiqueta eje Y')
plt.title('Gráfico de Dispersión')

# Mostrar leyenda
plt.legend()

# Mostrar la gráfica
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt

# Aquí defines tu patrón de entrada como un string
csv_data = """
V_BE,V_RB,I_B,V_BE1,V_RB1,I_B1,V_BE2,V_RB2,I_B2,
0.71,9.25,0.0000925,0.7,9.29,0.0000929,0.7,9.28,0.0000928,
0.709,8.93,0.0000893,0.703,9.03,0.0000903,0.7,9,0.00009,
0.707,8.1,0.000081,0.704,8.55,0.0000855,0.7,8.51,0.0000851,
0.7,7.08,0.0000708,0.703,7.98,0.0000798,0.7,7.99,0.0000799,
0.692,6.37,0.0000637,0.702,7.47,0.0000747,0.699,7.47,0.0000747,
0.685,5.77,0.0000577,0.702,7.02,0.0000702,0.699,6.96,0.0000696,
0.674,4.91,0.0000491,0.701,6.51,0.0000651,0.698,6.51,0.0000651,
0.67,4.67,0.0000467,0.699,6,0.00006,0.698,6.03,0.0000603,
0.666,4.11,0.0000411,0.694,5.56,0.0000556,0.697,5.57,0.0000557,
0.663,3.75,0.0000375,0.686,5.01,0.0000501,0.694,5.08,0.0000508,
0.66,3.45,0.0000345,0.679,4.52,0.0000452,0.686,4.56,0.0000456,
0.658,3.14,0.0000314,0.672,3.99,0.0000399,0.679,4.08,0.0000408,
0.657,2.81,0.0000281,0.666,3.49,0.0000349,0.671,3.5,0.000035,
0.651,2.48,0.0000248,0.661,3.03,0.0000303,0.664,2.96,0.0000296,
0.648,2.07,0.0000207,0.656,2.55,0.0000255,0.658,2.5,0.000025,
0.643,1.43,0.0000143,0.65,1.98,0.0000198,0.651,1.99,0.0000199,
0.637,1.04,0.0000104,0.644,1.5,0.000015,0.644,1.47,0.0000147,
0.635,0.83,0.0000083,0.637,1.03,0.0000103,0.639,1.09,0.0000109,
0.627,0.6,0.000006,0.622,0.45,0.0000045,0.623,0.53,0.0000053,
0.62,0.42,0.0000042,0.543,0.02,0.0000002,0.605,0.23,0.0000023,
0.615,0.208,0.00000208,0.615,0.29,0.0000029,0.556,0.04,0.0000004,
0.562,0.04,0.0000004,0.46,0.001,0.00000001,0.422,0.001,0.00000001,
0.49,0.02,0.0000002,0.049,0,0,0.566,0.05,0.0000005,
0.55,0.03,0.0000003,,,0,0.081,0,0,

"""

# Crea un archivo temporal con los datos
with open('datos_temporales.csv', 'w') as file:
    file.write(csv_data)

# Lee el archivo CSV
data = pd.read_csv('datos_temporales.csv',na_values=['NA', 'NaN', 'N/A'])

# Graficar el gráfico de dispersión para conjuntos de datos específicos
plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)


# Columnas de interés para el ajuste lineal
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

x_selected = []
y_selected = []

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]
    
    # Filtrar datos por encima de 0.65 en el eje x
    x_filtered = x[x > 0.67]
    y_filtered = y[x > 0.67]
    
    x_selected.extend(x_filtered)
    y_selected.extend(y_filtered)

x = np.array(x_selected)
y = np.array(y_selected)

# Realizar el ajuste lineal (regresión lineal)
coefficients = np.polyfit(x, y, 1)
poly = np.poly1d(coefficients)

# Calcular la intersección con el eje x (donde y = 0)
x_intercept = np.roots(poly - np.array(0))

# Obtener el valor real del punto de intersección en el eje x
x_intercept_real = x_intercept[np.isreal(x_intercept)].real

# Crear una secuencia de puntos para la línea de ajuste
x_line = np.linspace(min(x), max(x), 100)
y_line = poly(x_line)

# Graficar el gráfico de dispersión y la recta de ajuste
plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)

# Iterar a través de cada conjunto de datos
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]
    plt.scatter(x, y, color='C'+str(i), label=f'Datos {i+1}')  # Usando colores por defecto con 'C'+str(i)
plt.grid()

# Graficar solo los puntos seleccionados
plt.scatter(x_selected, y_selected, color='black', label='Datos seleccionados')

# Graficar la recta de ajuste
plt.plot(x_line, y_line, color='red', label='Ajuste lineal')

# Marcar la intersección con el eje x
plt.scatter(x_intercept_real, 0, color='red', s=100, label=f'Intersección')

# Etiquetas y título
plt.xlabel('Voltaje [V]')
plt.ylabel('Corriente [A]')
plt.title('Voltaje Umbral Datos Combinados')

# Mostrar leyenda
plt.legend()


# Mostrar la gráfica
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Tu código para leer los datos aquí...

# Columnas de interés para el ajuste lineal
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]

    # Filtrar datos por encima de x=0.65
    x_filtered = x[x > 0.65]
    y_filtered = y[x > 0.65]

    # Realizar el ajuste lineal solo para los datos filtrados
    coefficients = np.polyfit(x_filtered, y_filtered, 1)
    poly = np.poly1d(coefficients)

    # Calcular la intersección con el eje x (donde y = 0)
    x_intercept = np.roots(poly - np.array(0))
    x_intercept_real = x_intercept[np.isreal(x_intercept)].real

    # Calcular el r cuadrado utilizando linregress
    slope, intercept, r_value, p_value, std_err = linregress(x_filtered, y_filtered)
    r_squared = r_value**2

    # Crear una secuencia de puntos para la línea de ajuste
    x_line = np.linspace(min(x), max(x), 100)
    y_line = poly(x_line)

    plt.grid()

    # Graficar todos los puntos
    plt.scatter(x, y, label=f'V {i+1}')

    # Graficar solo los puntos filtrados
    plt.scatter(x_filtered, y_filtered)

    # Graficar la recta de ajuste solo para los datos filtrados
    plt.plot(x_line, y_line, label=f'Ajuste {i+1}')

    # Marcar la intersección con el eje x
    plt.scatter(x_intercept_real, np.zeros_like(x_intercept_real), label=f'V. Umbral {i+1}', marker='x', s=100)

    # Imprimir el r cuadrado
    print(f"Para el conjunto de datos {i+1}, el r cuadrado es: {r_squared}")

# Etiquetas y título
plt.xlabel('Voltaje [V]')
plt.ylabel('Corriente [A]')
plt.title('Voltaje Umbral Datos Independientes')

plt.ylim(-0.00001, max(y))  # Establece el límite inferior en -0.00001 y el límite superior en el máximo de los datos en y

# Mostrar leyenda
plt.legend()

# Mostrar la gráfica
plt.show()
# Out:
# Para el conjunto de datos 1, el r cuadrado es: 0.982668440998927
# Para el conjunto de datos 2, el r cuadrado es: 0.8400930682944168
# Para el conjunto de datos 3, el r cuadrado es: 0.8022354180354448

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Tu código para leer los datos aquí...

# Columnas de interés para el ajuste lineal
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]

    # Filtrar datos por encima de x=0.65
    x_filtered = x[x > 0.625]
    y_filtered = y[x > 0.625]

    # Realizar el ajuste lineal solo para los datos filtrados
    coefficients = np.polyfit(x_filtered, y_filtered, 1)
    poly = np.poly1d(coefficients)

    # Calcular la intersección con el eje x (donde y = 0)
    x_intercept = np.roots(poly - np.array(0))
    x_intercept_real = x_intercept[np.isreal(x_intercept)].real

    # Crear una secuencia de puntos para la línea de ajuste
    x_line = np.linspace(min(x), max(x), 100)
    y_line = poly(x_line)

    plt.grid()

    # Graficar todos los puntos
    plt.scatter(x, y, label=f'V {i+1}')

    # Graficar solo los puntos filtrados
    plt.scatter(x_filtered, y_filtered)

    # Graficar la recta de ajuste solo para los datos filtrados
    plt.plot(x_line, y_line, label=f'Ajuste {i+1}')

    # Marcar la intersección con el eje x
    plt.scatter(x_intercept_real, np.zeros_like(x_intercept_real), label=f'V. Umbral {i+1}', marker='x', s=100)

# Etiquetas y título
plt.xlabel('Voltaje [V]')
plt.ylabel('Corriente [A]')
plt.title('Voltaje Umbral Datos Independientes')

plt.ylim(-0.00001, max(y))  # Establece el límite inferior en -0.00001 y el límite superior en el máximo de los datos en y

# Mostrar leyenda
plt.legend()

# Mostrar la gráfica
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Tu código para leer los datos aquí...

# Columnas de interés para el ajuste lineal
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]

    # Filtrar datos por encima de x=0.65
    x_filtered = x[x > 0.625]
    y_filtered = y[x > 0.625]

    # Realizar el ajuste lineal solo para los datos filtrados
    coefficients = np.polyfit(x_filtered, y_filtered, 1)
    poly = np.poly1d(coefficients)

    # Calcular la intersección con el eje x (donde y = 0)
    x_intercept = np.roots(poly - np.array(0))
    x_intercept_real = x_intercept[np.isreal(x_intercept)].real

    # Calcular el r cuadrado utilizando linregress
    slope, intercept, r_value, p_value, std_err = linregress(x_filtered, y_filtered)
    r_squared = r_value**2

    # Crear una secuencia de puntos para la línea de ajuste
    x_line = np.linspace(min(x), max(x), 100)
    y_line = poly(x_line)

    # Graficar el gráfico de dispersión y la recta de ajuste
    plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)
    plt.grid()

    # Graficar todos los puntos
    plt.scatter(x, y, label=f'V {i+1}')

    # Graficar solo los puntos filtrados
    plt.scatter(x_filtered, y_filtered)

    # Graficar la recta de ajuste solo para los datos filtrados
    plt.plot(x_line, y_line, label=f'Ajuste {i+1}')

    # Marcar la intersección con el eje x
    plt.scatter(x_intercept_real, np.zeros_like(x_intercept_real), label=f'V. Umbral {i+1}', marker='x', s=100)

    # Imprimir el r cuadrado
    print(f"Para el conjunto de datos {i+1}, el r cuadrado es: {r_squared}")

    # Etiquetas y título
    plt.xlabel('Voltaje [V]')
    plt.ylabel('Corriente [A]')
    plt.title(f'Voltaje Umbral Datos Independientes - Conjunto {i+1}')

    plt.ylim(-0.00001, max(y))  # Establece el límite inferior en -0.00001 y el límite superior en el máximo de los datos en y


    # Mostrar leyenda
    plt.legend()

    # Mostrar la gráfica
    plt.show()
# Out:
# Para el conjunto de datos 1, el r cuadrado es: 0.9876170569715648
# Para el conjunto de datos 2, el r cuadrado es: 0.901735385918473
# Para el conjunto de datos 3, el r cuadrado es: 0.850190965667603

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Tu código para leer los datos aquí...

# Columnas de interés para el ajuste lineal
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]

    # Filtrar datos por encima de x=0.65
    x_filtered = x[x > 0.625]
    y_filtered = y[x > 0.625]

    # Realizar el ajuste lineal solo para los datos filtrados
    coefficients = np.polyfit(x_filtered, y_filtered, 1)
    poly = np.poly1d(coefficients)

    # Calcular la intersección con el eje x (donde y = 0)
    x_intercept = np.roots(poly - np.array(0))
    x_intercept_real = x_intercept[np.isreal(x_intercept)].real

    # Calcular el r cuadrado utilizando linregress
    slope, intercept, r_value, p_value, std_err = linregress(x_filtered, y_filtered)
    r_squared = r_value**2

    # Imprimir el valor de intersección en el eje x
    print(f"Para el conjunto de datos {i+1}, la intersección en el eje x es: {x_intercept_real}")

    # Resto del código (gráficos, etc.) si es necesario
# Out:
# Para el conjunto de datos 1, la intersección en el eje x es: [0.62685688]
# Para el conjunto de datos 2, la intersección en el eje x es: [0.63234838]
# Para el conjunto de datos 3, la intersección en el eje x es: [0.63509816]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Tu código para leer los datos aquí...

# Columnas de interés para el ajuste lineal
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]

    # Filtrar datos por encima de x=0.65
    x_filtered = x[x > 0.625]
    y_filtered = y[x > 0.625]

    # Realizar el ajuste lineal solo para los datos filtrados
    coefficients = np.polyfit(x_filtered, y_filtered, 1)
    poly = np.poly1d(coefficients)

    # Calcular la intersección con el eje x (donde y = 0)
    x_intercept = np.roots(poly - np.array(0))
    x_intercept_real = x_intercept[np.isreal(x_intercept)].real

    # Calcular el r cuadrado utilizando linregress
    slope, intercept, r_value, p_value, std_err = linregress(x_filtered, y_filtered)
    r_squared = r_value**2

    # Crear una secuencia de puntos para la línea de ajuste
    x_line = np.linspace(min(x), max(x), 100)
    y_line = poly(x_line)

    # Graficar el gráfico de dispersión y la recta de ajuste
    plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)
    plt.grid()

    # Graficar todos los puntos
    plt.scatter(x, y, label=f'V {i+1}')

    # Graficar solo los puntos filtrados
    plt.scatter(x_filtered, y_filtered)

    # Graficar la recta de ajuste solo para los datos filtrados
    plt.plot(x_line, y_line, label=f'Ajuste {i+1}')

    # Marcar la intersección con el eje x y el r cuadrado en la gráfica
    plt.text(0.5, 0.9, f'Intersección x: {x_intercept_real:.4f}\nR cuadrado: {r_squared:.4f}', transform=plt.gca().transAxes, fontsize=10, verticalalignment='top')

    # Etiquetas y título
    plt.xlabel('Voltaje [V]')
    plt.ylabel('Corriente [A]')
    plt.title(f'Voltaje Umbral Datos Independientes - Conjunto {i+1}')

    plt.ylim(-0.00001, max(y))  # Establece el límite inferior en -0.00001 y el límite superior en el máximo de los datos en y


    # Mostrar leyenda
    plt.legend()

    # Mostrar la gráfica
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\madro\OneDrive\Documents\.py\Python-\electronica\Transistores\Transistores.ipynb Celda 8 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/madro/OneDrive/Documents/.py/Python-/electronica/Transistores/Transistores.ipynb#X10sZmlsZQ%3D%3D?line=47'>48</a> plt.plot(x_line, y_line, label=f'Ajuste {i+1}')
#      <a href='vscode-notebook-cell:/c%3A/Users/madro/OneDrive/Documents/.py/Python-/electronica/Transistores/Transistores.ipynb#X10sZmlsZQ%3D%3D?line=49'>50</a> # Marcar la intersección con el eje x y el r cuadrado en la gráfica
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Tu código para leer los datos aquí...

# Columnas de interés para el ajuste lineal
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]

    # Filtrar datos por encima de x=0.65
    x_filtered = x[x > 0.625]
    y_filtered = y[x > 0.625]

    # Realizar el ajuste lineal solo para los datos filtrados
    coefficients = np.polyfit(x_filtered, y_filtered, 1)
    poly = np.poly1d(coefficients)

    # Calcular la intersección con el eje x (donde y = 0)
    x_intercept = np.roots(poly - np.array(0))
    x_intercept_real = x_intercept[np.isreal(x_intercept)].real

    # Calcular el r cuadrado utilizando linregress
    slope, intercept, r_value, p_value, std_err = linregress(x_filtered, y_filtered)
    r_squared = r_value**2

    # Crear una secuencia de puntos para la línea de ajuste
    x_line = np.linspace(min(x), max(x), 100)
    y_line = poly(x_line)

    # Graficar el gráfico de dispersión y la recta de ajuste
    plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)
    plt.grid()

    # Graficar todos los puntos
    plt.scatter(x, y, label=f'V {i+1}')

    # Graficar solo los puntos filtrados
    plt.scatter(x_filtered, y_filtered)

    # Graficar la recta de ajuste solo para los datos filtrados
    plt.plot(x_line, y_line, label=f'Ajuste {i+1}')

    # Formatear texto con la información a mostrar en el gráfico
    info_text = f'Intersección x: {x_intercept_real[0]:.4f}\nR cuadrado: {r_squared:.4f}'

    # Mostrar la información en el gráfico
    plt.text(0.5, 0.9, info_text, transform=plt.gca().transAxes, fontsize=10, verticalalignment='top')

    # Etiquetas y título
    plt.xlabel('Voltaje [V]')
    plt.ylabel('Corriente [A]')
    plt.title(f'Voltaje Umbral Datos Independientes - Conjunto {i+1}')

    plt.ylim(-0.00001, max(y))  # Establece el límite inferior en -0.00001 y el límite superior en el máximo de los datos en y


    # Mostrar leyenda
    plt.legend()

    # Mostrar la gráfica
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Tu código para leer los datos aquí...

# Columnas de interés para el ajuste lineal
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]

    # Filtrar datos por encima de x=0.65
    x_filtered = x[x > 0.625]
    y_filtered = y[x > 0.625]

    # Realizar el ajuste lineal solo para los datos filtrados
    coefficients = np.polyfit(x_filtered, y_filtered, 1)
    poly = np.poly1d(coefficients)

    # Calcular la intersección con el eje x (donde y = 0)
    x_intercept = np.roots(poly - np.array(0))
    x_intercept_real = x_intercept[np.isreal(x_intercept)].real

    # Calcular el r cuadrado utilizando linregress
    slope, intercept, r_value, p_value, std_err = linregress(x_filtered, y_filtered)
    r_squared = r_value**2

    # Crear una secuencia de puntos para la línea de ajuste
    x_line = np.linspace(min(x), max(x), 100)
    y_line = poly(x_line)

    # Obtener la pendiente del ajuste lineal
    slope_of_fit = coefficients[0]

    # Graficar el gráfico de dispersión y la recta de ajuste
    plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)
    plt.grid()

    # Graficar todos los puntos
    plt.scatter(x, y, label=f'V {i+1}')

    # Graficar solo los puntos filtrados
    plt.scatter(x_filtered, y_filtered)

    # Graficar la recta de ajuste solo para los datos filtrados
    plt.plot(x_line, y_line, label=f'Ajuste {i+1}')

    # Formatear texto con la información a mostrar en el gráfico
    info_text = f'Intersección x: {x_intercept_real[0]:.4f}\nPendiente: {slope_of_fit:.4f}\nR cuadrado: {r_squared:.4f}'

    # Mostrar la información en el gráfico
    plt.text(0.5, 0.9, info_text, transform=plt.gca().transAxes, fontsize=10, verticalalignment='top')

    # Etiquetas y título
    plt.xlabel('Voltaje [V]')
    plt.ylabel('Corriente [A]')
    plt.title(f'Voltaje Umbral Datos Independientes - Conjunto {i+1}')

    plt.ylim(-0.00001, max(y))  # Establece el límite inferior en -0.00001 y el límite superior en el máximo de los datos en y

    # Mostrar leyenda
    plt.legend()

    # Mostrar la gráfica
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Tu código para leer los datos aquí...

# Columnas de interés para el ajuste lineal
x_columns = ['V_BE', 'V_BE1', 'V_BE2']
y_columns = ['I_B', 'I_B1', 'I_B2']

# Iterar a través de cada par de columnas
for i in range(len(x_columns)):
    x = data[x_columns[i]]
    y = data[y_columns[i]]

    # Filtrar datos por encima de x=0.65
    x_filtered = x[x > 0.625]
    y_filtered = y[x > 0.625]

    # Realizar el ajuste lineal solo para los datos filtrados
    coefficients = np.polyfit(x_filtered, y_filtered, 1)
    poly = np.poly1d(coefficients)

    # Calcular la intersección con el eje x (donde y = 0)
    x_intercept = np.roots(poly - np.array(0))
    x_intercept_real = x_intercept[np.isreal(x_intercept)].real

    # Calcular el r cuadrado utilizando linregress
    slope, intercept, r_value, p_value, std_err = linregress(x_filtered, y_filtered)
    r_squared = r_value**2

    # Crear una secuencia de puntos para la línea de ajuste
    x_line = np.linspace(min(x), max(x), 100)
    y_line = poly(x_line)

    # Obtener la pendiente y la intersección del ajuste lineal
    slope_of_fit = coefficients[0]
    intercept_of_fit = coefficients[1]

    # Construir la ecuación del ajuste lineal
    equation_of_fit = f"y = {slope_of_fit:.4f}x + {intercept_of_fit:.4f}"

    # Graficar el gráfico de dispersión y la recta de ajuste
    plt.figure(figsize=(8, 6))  # Tamaño de la figura (opcional)
    plt.grid()

    # Graficar todos los puntos
    plt.scatter(x, y, label=f'V {i+1}')

    # Graficar solo los puntos filtrados
    plt.scatter(x_filtered, y_filtered)

    # Graficar la recta de ajuste solo para los datos filtrados
    plt.plot(x_line, y_line, label=f'Ajuste {i+1}')

    # Formatear texto con la información a mostrar en el gráfico
    info_text = f'Intersección x: {x_intercept_real[0]:.4f}\nPendiente: {slope_of_fit:.4f}\nR cuadrado: {r_squared:.4f}\n{equation_of_fit}'

    # Mostrar la información en el gráfico
    plt.text(0.5, 0.9, info_text, transform=plt.gca().transAxes, fontsize=10, verticalalignment='top')

    # Etiquetas y título
    plt.xlabel('Voltaje [V]')
    plt.ylabel('Corriente [A]')
    plt.title(f'Voltaje Umbral Datos Independientes - Conjunto {i+1}')

    plt.ylim(-0.00001, max(y))  # Establece el límite inferior en -0.00001 y el límite superior en el máximo de los datos en y

    # Mostrar leyenda
    plt.legend()

    # Mostrar la gráfica
    plt.show()
