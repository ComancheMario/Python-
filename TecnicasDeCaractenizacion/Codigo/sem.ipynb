# %%
import matplotlib.pyplot as plt

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    lines = file.readlines()
    for line in lines:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Graficar los datos
plt.figure(figsize=(8, 6))  # Tamaño del gráfico (opcional)
plt.plot(x_values, y_values, 'o-')  # 'o-' para puntos y líneas
plt.xlabel('Eje X')  # Etiqueta del eje X
plt.ylabel('Eje Y')  # Etiqueta del eje Y
plt.title('Gráfico de datos')  # Título del gráfico
plt.grid(True)  # Mostrar cuadrícula (opcional)
plt.show()  # Mostrar el gráfico
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\madro\OneDrive\Documents\.py\Python-\TecnicasDeCaractenizacion\Codigo\sem.ipynb Celda 1 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/madro/OneDrive/Documents/.py/Python-/TecnicasDeCaractenizacion/Codigo/sem.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>     for line in lines:
#      <a href='vscode-notebook-cell:/c%3A/Users/madro/OneDrive/Documents/.py/Python-/TecnicasDeCaractenizacion/Codigo/sem.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a>         data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/madro/OneDrive/Documents/.py/Python-/TecnicasDeCaractenizacion/Codigo/sem.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a>         x_values.append(float(data[0]))
# ...

# %%
import matplotlib.pyplot as plt

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Graficar los datos
plt.figure(figsize=(8, 6))  # Tamaño del gráfico (opcional)
plt.plot(x_values, y_values, 'o-')  # 'o-' para puntos y líneas
plt.xlabel('Eje X')  # Etiqueta del eje X
plt.ylabel('Eje Y')  # Etiqueta del eje Y
plt.title('Gráfico de datos')  # Título del gráfico
plt.grid(True)  # Mostrar cuadrícula (opcional)
plt.show()  # Mostrar el gráfico

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Graficar los datos
plt.figure(figsize=(8, 6))  # Tamaño del gráfico (opcional)
plt.plot(x_values, y_values, 'o-')  # 'o-' para puntos y líneas
plt.xlabel('Eje X')  # Etiqueta del eje X
plt.ylabel('Eje Y')  # Etiqueta del eje Y
plt.title('Gráfico de datos')  # Título del gráfico
plt.grid(True)  # Mostrar cuadrícula (opcional)

# Encontrar picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)  # Ajusta los parámetros según tu necesidad

# Marcar los picos en el gráfico
plt.plot([x_values[i] for i in peaks], [y_values[i] for i in peaks], 'ro', label='Picos')  # Marcador 'ro' para los picos

plt.legend()  # Muestra la leyenda
plt.show()  # Mostrar el gráfico

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Graficar los datos
plt.figure(figsize=(8, 6))  # Tamaño del gráfico (opcional)
plt.plot(x_values, y_values, 'o-')  # 'o-' para puntos y líneas
plt.xlabel('Eje X')  # Etiqueta del eje X
plt.ylabel('Eje Y')  # Etiqueta del eje Y
plt.title('Gráfico de datos')  # Título del gráfico
plt.grid(True)  # Mostrar cuadrícula (opcional)

# Encontrar todos los picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)  # Ajusta los parámetros según tu necesidad

# Ordenar los picos por altura
sorted_peaks = sorted(peaks, key=lambda x: y_values[x], reverse=True)

# Seleccionar los 8 picos más altos
peaks_8 = sorted_peaks[:8]

# Marcar los picos en el gráfico
plt.plot([x_values[i] for i in peaks_8], [y_values[i] for i in peaks_8], 'ro', label='8 Picos')  # Marcador 'ro' para los picos

plt.legend()  # Muestra la leyenda
plt.show()  # Mostrar el gráfico

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Encontrar todos los picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)  # Ajusta los parámetros según tu necesidad

# Ordenar los picos por altura
sorted_peaks = sorted(peaks, key=lambda x: y_values[x], reverse=True)

# Seleccionar los 8 picos más altos
peaks_8 = sorted_peaks[:8]

# Graficar únicamente los picos resaltados
plt.figure(figsize=(8, 6))  # Tamaño del gráfico (opcional)
plt.plot([x_values[i] for i in peaks_8], [y_values[i] for i in peaks_8], 'ro', label='8 Picos')  # Marcador 'ro' para los picos
plt.xlabel('Eje X')  # Etiqueta del eje X
plt.ylabel('Eje Y')  # Etiqueta del eje Y
plt.title('Gráfico de datos con 8 picos más altos')  # Título del gráfico
plt.legend()  # Muestra la leyenda
plt.grid(True)  # Mostrar cuadrícula (opcional)
plt.show()  # Mostrar el gráfico

# %%
import pandas as pd
from scipy.signal import find_peaks

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Encontrar todos los picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)  # Ajusta los parámetros según tu necesidad

# Ordenar los picos por altura
sorted_peaks = sorted(peaks, key=lambda x: y_values[x], reverse=True)

# Seleccionar los 8 picos más altos
peaks_8 = sorted_peaks[:8]

# Crear un DataFrame con los valores de los picos seleccionados
data = {'Eje X': [x_values[i] for i in peaks_8], 'Eje Y': [y_values[i] for i in peaks_8]}
df = pd.DataFrame(data)

# Imprimir la tabla
print(df)
# Guardamos los datos en un archivo CSV
df.to_csv('anchos_gaussianas.csv', index=False)
# Out:
#     Eje X   Eje Y
# 0  0.5275  3218.0
# 1  0.0026  2465.0
# 2  6.4020  1395.0
# 3  0.7125  1268.0
# 4  6.2920   331.0
# 5  4.5021   251.0
# 6  7.0369   213.0
# 7  6.5169   206.0

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Suponiendo que tienes los valores de los picos en la variable 'peaks_8' (lista de índices)
# y_values contiene los valores de tu eje Y

# Función gaussiana
def gaussian(x, amplitude, mean, stddev):
    return amplitude * np.exp(-((x - mean) / stddev) ** 2)

# Crear arrays para los datos de los picos
x_peaks = np.array([x_values[i] for i in peaks_8])
y_peaks = np.array([y_values[i] for i in peaks_8])

# Ajustar una función gaussiana a cada pico
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, 'b-', label='Datos originales')

for i in range(len(peaks_8)):
    # Definir un rango más estrecho para el ajuste de la gaussiana alrededor de cada pico
    peak_range = 20  # Rango alrededor del pico
    peak_position = peaks_8[i]  # Posición del pico
    
    peak_start = max(0, peak_position - peak_range)
    peak_end = min(len(x_values) - 1, peak_position + peak_range)
    
    x_fit = x_values[peak_start:peak_end]
    y_fit = y_values[peak_start:peak_end]
    
    # Estimar parámetros iniciales para la gaussiana
    amplitude_guess = max(y_fit) - min(y_fit)
    mean_guess = x_values[peaks_8[i]]
    stddev_guess = np.std(y_fit)
    
    # Ajustar gaussiana a un pico específico
    popt, pcov = curve_fit(gaussian, x_fit, y_fit, p0=[amplitude_guess, mean_guess, stddev_guess])
    
    # Generar puntos a lo largo del eje X para la curva gaussiana ajustada
    x_fit = np.linspace(x_values[peak_start], x_values[peak_end - 1], 100)
    y_fit = gaussian(x_fit, *popt)
    
    # Graficar la gaussiana ajustada
    plt.plot(x_fit, y_fit, label=f'Pico {i+1}')
    plt.scatter(x_values[peaks_8[i]], y_values[peaks_8[i]], color='red')  # Marcar el pico original

plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Ajuste de Gaussianas a los 8 picos')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.optimize import curve_fit

# Función gaussiana
def gaussian(x, amplitude, mean, stddev):
    return amplitude * np.exp(-((x - mean) / stddev) ** 2)

# Creamos una función para el cálculo del FWHM
def calculate_fwhm(x, y):
    half_max = max(y) / 2.0
    idx_left = np.where(y > half_max)[0][0]
    idx_right = np.where(y > half_max)[0][-1]
    fwhm = x[idx_right] - x[idx_left]
    return fwhm

# Creamos listas para almacenar los anchos de cada gaussiana
widths = []

# Iteramos sobre cada pico para ajustar una gaussiana y calcular su ancho
for i in range(len(peaks_8)):
    # Definimos un rango para el ajuste de la gaussiana alrededor de cada pico
    peak_range = 20  # Rango alrededor del pico
    peak_position = peaks_8[i]  # Posición del pico
    
    peak_start = max(0, peak_position - peak_range)
    peak_end = min(len(x_values) - 1, peak_position + peak_range)
    
    x_fit = x_values[peak_start:peak_end]
    y_fit = y_values[peak_start:peak_end]
    
    # Estimamos parámetros iniciales para la gaussiana
    amplitude_guess = max(y_fit) - min(y_fit)
    mean_guess = x_values[peaks_8[i]]
    stddev_guess = np.std(y_fit)
    
    # Ajustamos una gaussiana a un pico específico
    popt, pcov = curve_fit(gaussian, x_fit, y_fit, p0=[amplitude_guess, mean_guess, stddev_guess])
    
    # Calculamos el ancho a media altura (FWHM) de la gaussiana ajustada
    x_fit = np.linspace(x_values[peak_start], x_values[peak_end - 1], 100)
    y_fit = gaussian(x_fit, *popt)
    
    fwhm = calculate_fwhm(x_fit, y_fit)
    widths.append(fwhm)

# Creamos una tabla con los anchos de cada gaussiana
import pandas as pd

data = {'Pico': [f'Pico {i+1}' for i in range(len(peaks_8))],
        'Ancho FWHM': widths}
df = pd.DataFrame(data)
print(df)
# Out:
#      Pico  Ancho FWHM
# 0  Pico 1      0.1949
# 1  Pico 2      0.1950
# 2  Pico 3      0.1950
# 3  Pico 4      0.1950
# 4  Pico 5      0.1950
# 5  Pico 6      0.1949
# 6  Pico 7      0.1950
# 7  Pico 8      0.1949
