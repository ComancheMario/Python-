# %%
import matplotlib.pyplot as plt

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Graficar los datos
plt.figure(figsize=(8, 6))  # Tamaño del gráfico (opcional)
plt.plot(x_values, y_values, 'o-')  # 'o-' para puntos y líneas
plt.xlabel('Eje X')  # Etiqueta del eje X
plt.ylabel('Eje Y')  # Etiqueta del eje Y
plt.title('Gráfico de datos')  # Título del gráfico
plt.grid(True)  # Mostrar cuadrícula (opcional)
plt.show()  # Mostrar el gráfico

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Graficar los datos
plt.figure(figsize=(8, 6))  # Tamaño del gráfico (opcional)
plt.plot(x_values, y_values, 'o-')  # 'o-' para puntos y líneas
plt.xlabel('Eje X')  # Etiqueta del eje X
plt.ylabel('Eje Y')  # Etiqueta del eje Y
plt.title('Gráfico de datos')  # Título del gráfico
plt.grid(True)  # Mostrar cuadrícula (opcional)

# Encontrar picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)  # Ajusta los parámetros según tu necesidad

# Marcar los picos en el gráfico
plt.plot([x_values[i] for i in peaks], [y_values[i] for i in peaks], 'ro', label='Picos')  # Marcador 'ro' para los picos

plt.legend()  # Muestra la leyenda
plt.show()  # Mostrar el gráfico

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Graficar los datos
plt.figure(figsize=(8, 6))  # Tamaño del gráfico (opcional)
plt.plot(x_values, y_values, 'o-')  # 'o-' para puntos y líneas
plt.xlabel('Eje X')  # Etiqueta del eje X
plt.ylabel('Eje Y')  # Etiqueta del eje Y
plt.title('Gráfico de datos')  # Título del gráfico
plt.grid(True)  # Mostrar cuadrícula (opcional)

# Encontrar todos los picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)  # Ajusta los parámetros según tu necesidad

# Ordenar los picos por altura
sorted_peaks = sorted(peaks, key=lambda x: y_values[x], reverse=True)

# Seleccionar los 8 picos más altos
peaks_8 = sorted_peaks[:8]

# Marcar los picos en el gráfico
plt.plot([x_values[i] for i in peaks_8], [y_values[i] for i in peaks_8], 'ro', label='8 Picos')  # Marcador 'ro' para los picos

plt.legend()  # Muestra la leyenda
plt.show()  # Mostrar el gráfico

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Encontrar todos los picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)  # Ajusta los parámetros según tu necesidad

# Ordenar los picos por altura
sorted_peaks = sorted(peaks, key=lambda x: y_values[x], reverse=True)

# Seleccionar los 8 picos más altos
peaks_8 = sorted_peaks[:8]

# Graficar únicamente los picos resaltados
plt.figure(figsize=(8, 6))  # Tamaño del gráfico (opcional)
plt.plot([x_values[i] for i in peaks_8], [y_values[i] for i in peaks_8], 'ro', label='8 Picos')  # Marcador 'ro' para los picos
plt.xlabel('Eje X')  # Etiqueta del eje X
plt.ylabel('Eje Y')  # Etiqueta del eje Y
plt.title('Gráfico de datos con 8 picos más altos')  # Título del gráfico
plt.legend()  # Muestra la leyenda
plt.grid(True)  # Mostrar cuadrícula (opcional)
plt.show()  # Mostrar el gráfico

# %%
import pandas as pd
from scipy.signal import find_peaks

# Listas para almacenar los datos leídos del archivo
x_values = []
y_values = []

# Lee los datos del archivo, saltando la primera línea
with open('C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\Hexaferrita SrTi4-plana- edx zona oscurz.txt', 'r') as file:
    next(file)  # Salta la primera línea
    for line in file:
        data = line.split()  # Cambia el método de separación si es necesario (',' por ejemplo)
        x_values.append(float(data[0]))
        y_values.append(float(data[1]))

# Encontrar todos los picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)  # Ajusta los parámetros según tu necesidad

# Ordenar los picos por altura
sorted_peaks = sorted(peaks, key=lambda x: y_values[x], reverse=True)

# Seleccionar los 8 picos más altos
peaks_8 = sorted_peaks[:8]

# Crear un DataFrame con los valores de los picos seleccionados
data = {'Eje X': [x_values[i] for i in peaks_8], 'Eje Y': [y_values[i] for i in peaks_8]}
df = pd.DataFrame(data)

# Imprimir la tabla
print(df)
# Guardamos los datos en un archivo CSV
df.to_csv('anchos_gaussianas.csv', index=False)
# Out:
#     Eje X   Eje Y
# 0  0.5275  3218.0
# 1  0.0026  2465.0
# 2  6.4020  1395.0
# 3  0.7125  1268.0
# 4  6.2920   331.0
# 5  4.5021   251.0
# 6  7.0369   213.0
# 7  6.5169   206.0

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# Suponiendo que tienes los valores de los picos en la variable 'peaks_8' (lista de índices)
# y_values contiene los valores de tu eje Y

# Función gaussiana
def gaussian(x, amplitude, mean, stddev):
    return amplitude * np.exp(-((x - mean) / stddev) ** 2)

# Crear arrays para los datos de los picos
x_peaks = np.array([x_values[i] for i in peaks_8])
y_peaks = np.array([y_values[i] for i in peaks_8])

# Ajustar una función gaussiana a cada pico
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, 'b-', label='Datos originales')

for i in range(len(peaks_8)):
    # Definir un rango más estrecho para el ajuste de la gaussiana alrededor de cada pico
    peak_range = 20  # Rango alrededor del pico
    peak_position = peaks_8[i]  # Posición del pico
    
    peak_start = max(0, peak_position - peak_range)
    peak_end = min(len(x_values) - 1, peak_position + peak_range)
    
    x_fit = x_values[peak_start:peak_end]
    y_fit = y_values[peak_start:peak_end]
    
    # Estimar parámetros iniciales para la gaussiana
    amplitude_guess = max(y_fit) - min(y_fit)
    mean_guess = x_values[peaks_8[i]]
    stddev_guess = np.std(y_fit)
    
    # Ajustar gaussiana a un pico específico
    popt, pcov = curve_fit(gaussian, x_fit, y_fit, p0=[amplitude_guess, mean_guess, stddev_guess])
    
    # Generar puntos a lo largo del eje X para la curva gaussiana ajustada
    x_fit = np.linspace(x_values[peak_start], x_values[peak_end - 1], 100)
    y_fit = gaussian(x_fit, *popt)
    
    # Graficar la gaussiana ajustada
    plt.plot(x_fit, y_fit, label=f'Pico {i+1}')
    plt.scatter(x_values[peaks_8[i]], y_values[peaks_8[i]], color='red')  # Marcar el pico original

plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Ajuste de Gaussianas a los 8 picos')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# c:\Users\madro\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\optimize\_minpack_py.py:1010: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
# Crear listas para almacenar áreas bajo la curva para cada pico
areas_picos = []

# Iterar sobre cada pico para calcular su área bajo la curva
for i in range(len(peaks_8)):
    # Definir un rango alrededor de cada pico
    peak_range = 20  # Rango alrededor del pico
    peak_position = peaks_8[i]  # Posición del pico
    
    peak_start = max(0, peak_position - peak_range)
    peak_end = min(len(x_values) - 1, peak_position + peak_range)
    
    # Calcular el área bajo la curva para el rango alrededor del pico actual
    area_pico = np.trapz(y_values[peak_start:peak_end], x=x_values[peak_start:peak_end])
    areas_picos.append(area_pico)

# Mostrar las áreas bajo la curva para cada pico
for i, area in enumerate(areas_picos):
    print(f"Área bajo la curva del Pico {i+1}: {area}")
# Out:
# Área bajo la curva del Pico 1: 265.77344999999997
# Área bajo la curva del Pico 2: 148.89749999999998
# Área bajo la curva del Pico 3: 181.56750000000008
# Área bajo la curva del Pico 4: 123.31749999999998
# Área bajo la curva del Pico 5: 93.69999999999938
# Área bajo la curva del Pico 6: 33.565150000000045
# Área bajo la curva del Pico 7: 27.197499999999998
# Área bajo la curva del Pico 8: 74.16310000000023

# %%
# Calcular el área bajo la curva de los datos originales
area_bajo_curva = np.trapz(y_values, x=x_values)
print(f"El área bajo la curva de los datos originales es: {area_bajo_curva}")
# Out:
# El área bajo la curva de los datos originales es: 1289.26185

# %%
import numpy as np
from scipy.optimize import curve_fit

# Función gaussiana
def gaussian(x, amplitude, mean, stddev):
    return amplitude * np.exp(-((x - mean) / stddev) ** 2)

# Creamos una función para el cálculo del FWHM
def calculate_fwhm(x, y):
    half_max = max(y) / 2.0
    idx_left = np.where(y > half_max)[0][0]
    idx_right = np.where(y > half_max)[0][-1]
    fwhm = x[idx_right] - x[idx_left]
    return fwhm

# Creamos listas para almacenar los anchos de cada gaussiana
widths = []

# Iteramos sobre cada pico para ajustar una gaussiana y calcular su ancho
for i in range(len(peaks_8)):
    # Definimos un rango para el ajuste de la gaussiana alrededor de cada pico
    peak_range = 20  # Rango alrededor del pico
    peak_position = peaks_8[i]  # Posición del pico
    
    peak_start = max(0, peak_position - peak_range)
    peak_end = min(len(x_values) - 1, peak_position + peak_range)
    
    x_fit = x_values[peak_start:peak_end]
    y_fit = y_values[peak_start:peak_end]
    
    # Estimamos parámetros iniciales para la gaussiana
    amplitude_guess = max(y_fit) - min(y_fit)
    mean_guess = x_values[peaks_8[i]]
    stddev_guess = np.std(y_fit)
    
    # Ajustamos una gaussiana a un pico específico
    popt, pcov = curve_fit(gaussian, x_fit, y_fit, p0=[amplitude_guess, mean_guess, stddev_guess])
    
    # Calculamos el ancho a media altura (FWHM) de la gaussiana ajustada
    x_fit = np.linspace(x_values[peak_start], x_values[peak_end - 1], 100)
    y_fit = gaussian(x_fit, *popt)
    
    fwhm = calculate_fwhm(x_fit, y_fit)
    widths.append(fwhm)

# Creamos una tabla con los anchos de cada gaussiana
import pandas as pd

data = {'Pico': [f'Pico {i+1}' for i in range(len(peaks_8))],
        'Ancho FWHM': widths}
df = pd.DataFrame(data)
print(df)
# Out:
#      Pico  Ancho FWHM
# 0  Pico 1      0.1949
# 1  Pico 2      0.1950
# 2  Pico 3      0.1950
# 3  Pico 4      0.1950
# 4  Pico 5      0.1950
# 5  Pico 6      0.1949
# 6  Pico 7      0.1950
# 7  Pico 8      0.1949

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import find_peaks

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'  # Reemplaza 'ruta_del_archivo.csv' con la ruta de tu archivo CSV
data = pd.read_csv(file_path)

# Obtener los valores de las columnas 'Eje X' y 'Eje Y'
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()


# Graficar los datos
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values, 'o-')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de datos')
plt.grid(True)

# Encontrar todos los picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)

# Ordenar los picos por altura
sorted_peaks = sorted(peaks, key=lambda x: y_values[x], reverse=True)

# Seleccionar los 15 picos más altos
peaks_15 = sorted_peaks[:15]

# Marcar los picos en el gráfico
plt.plot([x_values[i] for i in peaks_15], [y_values[i] for i in peaks_15], 'ro', label='15 Picos')

plt.legend()
plt.show()

# %%
import pandas as pd
from scipy.signal import find_peaks


# Encontrar todos los picos
peaks, _ = find_peaks(y_values, distance=20, prominence=0.5)

# Ordenar los picos por altura
sorted_peaks = sorted(peaks, key=lambda x: y_values[x], reverse=True)

# Seleccionar los 15 picos más altos
peaks_15 = sorted_peaks[:15]

# Crear un DataFrame con los valores de los picos
picos_df = pd.DataFrame({
    'Posición': [x_values[i] for i in peaks_15],
    'Altura': [y_values[i] for i in peaks_15]
})

print(picos_df)
# Out:
#      Posición  Altura
# 0   33.289995    3282
# 1   35.758489    2594
# 2   54.193409    2040
# 3   32.502178    2024
# 4   49.597809    1844
# 5   24.256359    1835
# 6   34.314158    1704
# 7   41.010603    1603
# 8   64.119904    1554
# 9   28.090402    1521
# 10  30.874023    1515
# 11  62.570531    1466
# 12  14.723772    1378
# 13  14.040997    1340
# 14  15.354026    1339

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import find_peaks

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'
data = pd.read_csv(file_path)

# Obtener los valores de las columnas 'Eje X' y 'Eje Y'
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()

# Función de suavizado por promedio avanzado
def advanced_averaging(data, window_size):
    smoothed_data = []
    half_window = window_size // 2
    
    for i in range(len(data)):
        if i < half_window or i >= len(data) - half_window:
            smoothed_data.append(data[i])
        else:
            window = data[i - half_window: i + half_window + 1]
            smoothed_value = sum(window) / window_size
            smoothed_data.append(smoothed_value)
    
    return smoothed_data

# Aplicar suavizado a los datos 'y_values'
window_size = 5  # Modifica el tamaño de la ventana según lo deseado
y_smoothed = advanced_averaging(y_values, window_size)

# Graficar los datos suavizados
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_smoothed, 'b-', label='Datos suavizados')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico de datos suavizados')
plt.grid(True)

# Encontrar todos los picos en los datos suavizados
peaks, _ = find_peaks(y_smoothed, distance=20, prominence=0.5)

# Ordenar los picos por altura
sorted_peaks = sorted(peaks, key=lambda x: y_smoothed[x], reverse=True)

# Seleccionar los 15 picos más altos
peaks_15 = sorted_peaks[:15]

# Marcar los picos en el gráfico de datos suavizados
plt.plot([x_values[i] for i in peaks_15], [y_smoothed[i] for i in peaks_15], 'ro', label='15 Picos')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
import numpy as np

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'
data = pd.read_csv(file_path)

# Obtener los valores de las columnas 'Eje X' y 'Eje Y'
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()

# Función de suavizado por promedio avanzado
def advanced_averaging(data, window_size):
    smoothed_data = []
    half_window = window_size // 2
    
    for i in range(len(data)):
        if i < half_window or i >= len(data) - half_window:
            smoothed_data.append(data[i])
        else:
            window = data[i - half_window: i + half_window + 1]
            smoothed_value = sum(window) / window_size
            smoothed_data.append(smoothed_value)
    
    return smoothed_data

# Aplicar suavizado a los datos 'y_values'
window_size = 5
y_smoothed = advanced_averaging(y_values, window_size)

# Encontrar todos los picos en los datos suavizados
peaks, _ = find_peaks(y_smoothed, distance=20, prominence=0.5)

# Ordenar los picos por altura y seleccionar los picos por encima de 1000
sorted_peaks = sorted(peaks, key=lambda x: y_smoothed[x], reverse=True)
peaks_above_1000 = [x for x in sorted_peaks if y_smoothed[x] > 1000]

# Función gaussiana
def gaussian_function(x, a, b, c):
    return a * np.exp(-(x - b)**2 / (2 * c**2))

# Graficar los datos suavizados
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_smoothed, 'b-', label='Datos suavizados')

for peak in peaks_above_1000:
    x_peak = x_values[peak]
    y_peak = y_smoothed[peak]
    
    # Ampliar el rango de la ventana para el ajuste gaussiano
    window_range = 20  # Ampliar el rango a 20 puntos alrededor del pico
    x_window = x_values[peak - window_range//2: peak + window_range//2 + 1]
    y_window = y_smoothed[peak - window_range//2: peak + window_range//2 + 1]
    
    # Ajuste de la función gaussiana
    try:
        popt, _ = curve_fit(gaussian_function, x_window, y_window, p0=[y_peak, x_peak, 0.1])
        
        # Graficar la función gaussiana ajustada
        plt.plot(x_window, gaussian_function(x_window, *popt), 'r--', label='Ajuste gaussiano')
        
        # Marcar los picos
        plt.plot(x_values[peak], y_smoothed[peak], 'ro')
    except RuntimeError:
        pass  # En caso de que el ajuste falle para algún pico

plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Ajuste gaussiano para picos por encima de 1000 con marcas de picos')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\madro\OneDrive\Documents\.py\Python-\TecnicasDeCaractenizacion\Codigo\sem.ipynb Celda 17 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/madro/OneDrive/Documents/.py/Python-/TecnicasDeCaractenizacion/Codigo/sem.ipynb#X33sZmlsZQ%3D%3D?line=57'>58</a> # Ajuste de la función gaussiana
#      <a href='vscode-notebook-cell:/c%3A/Users/madro/OneDrive/Documents/.py/Python-/TecnicasDeCaractenizacion/Codigo/sem.ipynb#X33sZmlsZQ%3D%3D?line=58'>59</a> try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/madro/OneDrive/Documents/.py/Python-/TecnicasDeCaractenizacion/Codigo/sem.ipynb#X33sZmlsZQ%3D%3D?line=59'>60</a>     popt, _ = curve_fit(gaussian_function, x_window, y_window, p0=[y_peak, x_peak, 0.1])
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
import numpy as np

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'
data = pd.read_csv(file_path)

# Obtener los valores de las columnas 'Eje X' y 'Eje Y'
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()

# Encontrar todos los picos en los datos originales
peaks, _ = find_peaks(y_values, distance=20, prominence=1000)

# Función gaussiana
def gaussian_function(x, a, b, c):
    return a * np.exp(-(x - b)**2 / (2 * c**2))

# Graficar los datos y los picos detectados
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values, 'b-', label='Datos')

# Ajustar y mostrar la curva gaussiana para cada pico
for peak in peaks:
    x_peak = x_values[peak]
    y_peak = y_values[peak]
    
    window_range = 20  # Ampliar el rango a 20 puntos alrededor del pico
    x_window = x_values[peak - window_range//2: peak + window_range//2 + 1]
    y_window = y_values[peak - window_range//2: peak + window_range//2 + 1]
    
    try:
        popt, _ = curve_fit(gaussian_function, x_window, y_window, p0=[y_peak, x_peak, 0.1])
        
        # Graficar la función gaussiana ajustada
        plt.plot(x_window, gaussian_function(x_window, *popt), 'r--', label='Ajuste gaussiano')
        
        # Marcar los picos
        plt.plot(x_values[peak], y_values[peak], 'ro')
    except RuntimeError:
        pass  # En caso de que el ajuste falle para algún pico

plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Ajuste gaussiano para picos por encima de 1000 con marcas de picos')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
import numpy as np

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'
data = pd.read_csv(file_path)

# Obtener los valores de las columnas 'Eje X' y 'Eje Y'
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()

# Encontrar todos los picos en los datos originales
peaks, _ = find_peaks(y_values, distance=20, prominence=500)  # Reducir el umbral de prominencia a 500

# Función gaussiana
def gaussian_function(x, a, b, c):
    return a * np.exp(-(x - b)**2 / (2 * c**2))

# Graficar los datos y los picos detectados
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values, 'b-', label='Datos')

# Ajustar y mostrar la curva gaussiana para cada pico
for peak in peaks:
    x_peak = x_values[peak]
    y_peak = y_values[peak]
    
    window_range = 20  # Ampliar el rango a 20 puntos alrededor del pico
    x_window = x_values[peak - window_range//2: peak + window_range//2 + 1]
    y_window = y_values[peak - window_range//2: peak + window_range//2 + 1]
    
    try:
        popt, _ = curve_fit(gaussian_function, x_window, y_window, p0=[y_peak, x_peak, 0.1])
        
        # Graficar la función gaussiana ajustada
        plt.plot(x_window, gaussian_function(x_window, *popt), 'r--', label='Ajuste gaussiano')
        
        # Marcar los picos
        plt.plot(x_values[peak], y_values[peak], 'ro')
    except RuntimeError:
        pass  # En caso de que el ajuste falle para algún pico

plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Ajuste gaussiano para picos con prominencia mayor a 500 con marcas de picos')
plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
import numpy as np

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'
data = pd.read_csv(file_path)

# Obtener los valores de las columnas 'Eje X' y 'Eje Y'
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()

# Encontrar todos los picos en los datos originales
peaks, _ = find_peaks(y_values, distance=20, prominence=500)  # Umbral de prominencia 500

# Función gaussiana
def gaussian_function(x, a, b, c):
    return a * np.exp(-(x - b)**2 / (2 * c**2))

# Crear un DataFrame para almacenar los resultados
results = {'Pico': [], 'Ancho': []}

# Ajustar y calcular el ancho para cada pico
for peak in peaks:
    x_peak = x_values[peak]
    y_peak = y_values[peak]
    
    window_range = 20  # Ampliar el rango a 20 puntos alrededor del pico
    x_window = x_values[peak - window_range//2: peak + window_range//2 + 1]
    y_window = y_values[peak - window_range//2: peak + window_range//2 + 1]
    
    try:
        popt, _ = curve_fit(gaussian_function, x_window, y_window, p0=[y_peak, x_peak, 0.1])
        
        # Obtener el ancho a media altura (FWHM)
        a, b, c = popt
        fwhm = 2 * np.sqrt(2 * np.log(2)) * np.abs(c)
        
        # Agregar los resultados al DataFrame
        results['Pico'].append(peak)
        results['Ancho'].append(fwhm)
    except RuntimeError:
        pass  # En caso de que el ajuste falle para algún pico

# Crear un DataFrame a partir de los resultados
table = pd.DataFrame(results)
print(table)
# Out:
#     Pico     Ancho
# 0    542  0.643013
# 1    794  0.917827
# 2    856  0.532917
# 3    886  0.381709
# 4    925  0.607140
# 5    980  0.456436
# 6   1180  0.752990
# 7   1507  0.605640
# 8   1682  0.557685
# 9   2001  0.778975
# 10  2060  0.804140

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
import numpy as np

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'
data = pd.read_csv(file_path)

# Obtener los valores de las columnas 'Eje X' y 'Eje Y'
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()

# Encontrar todos los picos en los datos originales
peaks, _ = find_peaks(y_values, distance=20, prominence=500)  # Reducir el umbral de prominencia a 500

# Función gaussiana
def gaussian_function(x, a, b, c):
    return a * np.exp(-(x - b)**2 / (2 * c**2))

# Graficar los datos y los picos detectados
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values, 'b-', label='Datos')

# Ajustar y mostrar la curva gaussiana para cada pico
for peak in peaks:
    x_peak = x_values[peak]
    y_peak = y_values[peak]
    
    window_range = 20  # Ampliar el rango a 20 puntos alrededor del pico
    x_window = x_values[peak - window_range//2: peak + window_range//2 + 1]
    y_window = y_values[peak - window_range//2: peak + window_range//2 + 1]
    
    try:
        popt, _ = curve_fit(gaussian_function, x_window, y_window, p0=[y_peak, x_peak, 0.1])
        
        # Graficar la función gaussiana ajustada
        plt.plot(x_window, gaussian_function(x_window, *popt), 'r--', label='Ajuste gaussiano')
        
        # Marcar los picos
        plt.plot(x_values[peak], y_values[peak], 'ro')
        
        # Etiquetar los picos
        plt.text(x_values[peak], y_values[peak], str(peak), ha='right', va='bottom', color='black', fontsize=8)
    except RuntimeError:
        pass  # En caso de que el ajuste falle para algún pico

plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Ajuste gaussiano para picos con prominencia mayor a 500 con marcas y etiquetas de picos')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
import numpy as np

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'
data = pd.read_csv(file_path)

# Obtener los valores de las columnas 'Eje X' y 'Eje Y'
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()

# Encontrar todos los picos en los datos originales
peaks, _ = find_peaks(y_values, distance=20, prominence=500)  # Reducir el umbral de prominencia a 500

# Función gaussiana
def gaussian_function(x, a, b, c):
    return a * np.exp(-(x - b)**2 / (2 * c**2))

# Graficar los datos y los picos detectados
plt.figure(figsize=(8, 6))
plt.plot(x_values, y_values, 'b-', label='Datos')

# Ajustar y mostrar la curva gaussiana para cada pico
for i, peak in enumerate(peaks, start=1):
    x_peak = x_values[peak]
    y_peak = y_values[peak]
    
    window_range = 20  # Ampliar el rango a 20 puntos alrededor del pico
    x_window = x_values[peak - window_range//2: peak + window_range//2 + 1]
    y_window = y_values[peak - window_range//2: peak + window_range//2 + 1]
    
    try:
        popt, _ = curve_fit(gaussian_function, x_window, y_window, p0=[y_peak, x_peak, 0.1])
        
        # Graficar la función gaussiana ajustada
        plt.plot(x_window, gaussian_function(x_window, *popt), 'r--', label='Ajuste gaussiano')
        
        # Marcar los picos
        plt.plot(x_values[peak], y_values[peak], 'ro')
        
        # Etiquetar los picos
        plt.text(x_values[peak], y_values[peak], f'Pico {i}', ha='right', va='bottom', color='black', fontsize=8)
    except RuntimeError:
        pass  # En caso de que el ajuste falle para algún pico

plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Ajuste gaussiano para picos con prominencia mayor a 500 con marcas y etiquetas de picos')
plt.grid(True)
plt.legend()
plt.show()

# %%
import pandas as pd
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
import numpy as np

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'
data = pd.read_csv(file_path)

# Obtener los valores de los ángulos ('2Theta') y cuentas ('cuenta')
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()

# Encontrar todos los picos en los datos originales
peaks, _ = find_peaks(y_values, distance=20, prominence=500)  # Reducir el umbral de prominencia a 500

# Función gaussiana
def gaussian_function(x, a, b, c):
    return a * np.exp(-(x - b)**2 / (2 * c**2))

# Crear un DataFrame para almacenar los resultados
results = {'Ángulo': [], 'Ancho': [], 'Etiqueta': []}

# Ajustar y calcular el ancho para cada pico
for i, peak in enumerate(peaks, start=1):
    x_peak = x_values[peak]
    y_peak = y_values[peak]
    
    window_range = 20  # Ampliar el rango a 20 puntos alrededor del pico
    x_window = x_values[peak - window_range//2: peak + window_range//2 + 1]
    y_window = y_values[peak - window_range//2: peak + window_range//2 + 1]
    
    try:
        popt, _ = curve_fit(gaussian_function, x_window, y_window, p0=[y_peak, x_peak, 0.1])
        
        # Obtener el ancho a media altura (FWHM)
        a, b, c = popt
        fwhm = 2 * np.sqrt(2 * np.log(2)) * np.abs(c)
        
        # Agregar los resultados al DataFrame
        results['Ángulo'].append(x_peak)  # Usar el ángulo original
        results['Ancho'].append(fwhm)
        results['Etiqueta'].append(f'Pico {i}')
    except RuntimeError:
        pass  # En caso de que el ajuste falle para algún pico

# Crear un DataFrame a partir de los resultados
table = pd.DataFrame(results)
print(table)
# Out:
#        Ángulo     Ancho Etiqueta
# 0   24.256359  0.643013   Pico 1
# 1   30.874023  0.917827   Pico 2
# 2   32.502178  0.532917   Pico 3
# 3   33.289995  0.381709   Pico 4
# 4   34.314158  0.607140   Pico 5
# 5   35.758489  0.456436   Pico 6
# 6   41.010603  0.752990   Pico 7
# 7   49.597809  0.605640   Pico 8
# 8   54.193409  0.557685   Pico 9
# 9   62.570531  0.778975  Pico 10
# 10  64.119904  0.804140  Pico 11

# %%
import pandas as pd
from scipy.signal import find_peaks
from scipy.optimize import curve_fit
import numpy as np

# Cargar el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\PowDLL_XY_XRD_Sunday, December 03, 2023.csv'
data = pd.read_csv(file_path)

# Obtener los valores de los ángulos ('2Theta') y cuentas ('cuenta')
x_values = data['2Theta'].tolist()
y_values = data['cuenta'].tolist()

# Encontrar todos los picos en los datos originales
peaks, _ = find_peaks(y_values, distance=20, prominence=500)  # Reducir el umbral de prominencia a 500

# Función gaussiana
def gaussian_function(x, a, b, c):
    return a * np.exp(-(x - b)**2 / (2 * c**2))

# Crear un DataFrame para almacenar los resultados
results = {'Ángulo': [], 'Ancho': [], 'Etiqueta': []}

# Ajustar y calcular el ancho para cada pico
for i, peak in enumerate(peaks, start=1):
    x_peak = x_values[peak]
    y_peak = y_values[peak]
    
    window_range = 20  # Ampliar el rango a 20 puntos alrededor del pico
    x_window = x_values[peak - window_range//2: peak + window_range//2 + 1]
    y_window = y_values[peak - window_range//2: peak + window_range//2 + 1]
    
    try:
        popt, _ = curve_fit(gaussian_function, x_window, y_window, p0=[y_peak, x_peak, 0.1])
        
        # Obtener el ancho a media altura (FWHM)
        a, b, c = popt
        fwhm = 2 * np.sqrt(2 * np.log(2)) * np.abs(c)
        
        # Agregar los resultados al DataFrame
        results['Ángulo'].append(x_peak)  # Usar el ángulo original
        results['Ancho'].append(fwhm)
        results['Etiqueta'].append(f'Pico {i}')
    except RuntimeError:
        pass  # En caso de que el ajuste falle para algún pico

# Crear un DataFrame a partir de los resultados
table = pd.DataFrame(results)

# Guardar el DataFrame como un archivo CSV
table.to_csv('resultados_picos.csv', index=False)

# %%
# Calcular el área bajo la curva para esos picos
areas_picos = []
for pico in picos_superiores_1000:
    # Definir la región sobre la cual calcular el área
    x_window = x_values[pico - window_range//2: pico + window_range//2 + 1]
    y_window = y_values[pico - window_range//2: pico + window_range//2 + 1]
    
    # Asegurarse de que las dimensiones sean las mismas
    min_len = min(len(x_window), len(y_window))
    x_window = x_window[:min_len]
    y_window = y_window[:min_len]
    
    # Calcular el área utilizando la suma de los trapecios
    area = np.trapz(y_window, x_window)
    areas_picos.append(area)

# Mostrar las áreas calculadas para los picos por encima de 1000
print("Áreas bajo la curva de los picos por encima de 1000:")
for i, area in enumerate(areas_picos, start=1):
    print(f"Pico {i}: {area}")
# Out:
# Áreas bajo la curva de los picos por encima de 1000:
# Pico 1: 0.0
# Pico 2: 0.0
# Pico 3: 0.0
# Pico 4: 0.0
# Pico 5: 0.0
# Pico 6: 0.0
# Pico 7: 0.0
# Pico 8: 0.0
# Pico 9: 0.0
# Pico 10: 0.0
# Pico 11: 615.5477608
# Pico 12: 614.878116265
# Pico 13: 612.9479643700001
# Pico 14: 612.9742249400001
# Pico 15: 614.31351401
# Pico 16: 614.3397745799999
# Pico 17: 613.9589963149999
# Pico 18: 614.1953414449999
# Pico 19: 614.2478625849999
# Pico 20: 614.3660351499999
# Pico 21: 614.3397745799998
# Pico 22: 614.4054260049999
# Pico 23: 614.2478625849999
# Pico 24: 613.4731757699998
# Pico 25: 613.880214605
# Pico 26: 613.512566625002
# Pico 27: 613.6044786199999
# Pico 28: 615.0094191149999
# Pico 29: 615.3508065249998
# Pico 30: 614.52359857
# Pico 31: 614.668031705
# Pico 32: 615.7053242200001
# Pico 33: 616.0467116299999
# Pico 34: 617.8455606749999
# Pico 35: 620.7867445149999
# Pico 36: 622.165424440002
# Pico 37: 622.887590115
# Pico 38: 624.37131232
# Pico 39: 625.1459991349999
# ...

# %%
from scipy.integrate import simps

# Obtener los picos a los que se les aplicó la función gaussiana
picos_gaussianos = sorted_peaks[:15]  # Suponiendo que 'sorted_peaks' contiene los índices de los picos seleccionados

# Calcular el área bajo la curva para esos picos
areas_picos = []
for pico in picos_gaussianos:
    # Definir la región sobre la cual calcular el área
    x_window = x_values[pico - window_range//2: pico + window_range//2 + 1]
    y_window = y_values[pico - window_range//2: pico + window_range//2 + 1]
    
    # Asegurarse de que las dimensiones sean las mismas
    min_len = min(len(x_window), len(y_window))
    x_window = x_window[:min_len]
    y_window = y_window[:min_len]
    
    # Calcular el área utilizando la suma de los trapecios
    area = np.trapz(y_window, x_window)
    areas_picos.append(area)

# Mostrar las áreas calculadas para los picos con función gaussiana
print("Áreas bajo la curva de los picos con función gaussiana:")
for i, area in enumerate(areas_picos, start=1):
    print(f"Pico {i}: {area}")
# Out:
# Áreas bajo la curva de los picos con función gaussiana:
# Pico 1: 968.3059976100037
# Pico 2: 873.741685040002
# Pico 3: 773.1111807999962
# Pico 4: 753.3501018750044
# Pico 5: 740.692507135
# Pico 6: 749.1878015300034
# Pico 7: 674.0300501900035
# Pico 8: 651.3015268550034
# Pico 9: 660.8078531949957
# Pico 10: 663.0006107900002
# Pico 11: 662.8955685099997
# Pico 12: 648.425994440004
# Pico 13: 665.4165832300021
# Pico 14: 664.4318118549999
# Pico 15: 665.8367523499996

# %%
from scipy.integrate import simps

# Crear una lista con los índices de los picos donde se aplicó la función gaussiana
picos_gaussianos = sorted_peaks[:11]  # Suponiendo que 'sorted_peaks' contiene los índices de los picos seleccionados

# Crear una lista para almacenar las áreas de los picos gaussiano
areas_picos_gaussianos = []

# Calcular el área bajo la curva para esos picos
for pico in picos_gaussianos:
    # Definir la región sobre la cual calcular el área
    x_window = x_values[pico - window_range//2: pico + window_range//2 + 1]
    y_window = y_values[pico - window_range//2: pico + window_range//2 + 1]
    
    # Asegurarse de que las dimensiones sean las mismas
    min_len = min(len(x_window), len(y_window))
    x_window = x_window[:min_len]
    y_window = y_window[:min_len]
    
    # Calcular el área utilizando la suma de los trapecios
    area = np.trapz(y_window, x_window)
    areas_picos_gaussianos.append(area)

# Mostrar las áreas calculadas para los picos con función gaussiana
print("Áreas bajo la curva de los picos con función gaussiana:")
for i, area in enumerate(areas_picos_gaussianos, start=1):
    print(f"Pico {i}: {area}")
# Out:
# Áreas bajo la curva de los picos con función gaussiana:
# Pico 1: 968.3059976100037
# Pico 2: 873.741685040002
# Pico 3: 773.1111807999962
# Pico 4: 753.3501018750044
# Pico 5: 740.692507135
# Pico 6: 749.1878015300034
# Pico 7: 674.0300501900035
# Pico 8: 651.3015268550034
# Pico 9: 660.8078531949957
# Pico 10: 663.0006107900002
# Pico 11: 662.8955685099997

# %%
from scipy.integrate import simps

# Calcular el área bajo la curva para todos los datos
area_total = simps(y_values, x_values)

print(f"El área bajo toda la curva de datos es: {area_total}")
# Out:
# El área bajo toda la curva de datos es: 88212.54376639248

# %% [markdown]
# ## w-H model ##

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Cargar los datos desde el archivo CSV
file_path = 'C:\\Users\\madro\\OneDrive\\Documents\\.py\\Python-\\TecnicasDeCaractenizacion\\Data\\W-H.csv'  # Reemplaza 'tu_archivo.csv' con la ruta de tu archivo CSV
data = pd.read_csv(file_path)

# Extraer las columnas necesarias para el ajuste (suponiendo 'x' y 'y')
x = data['4 SEN (TETA)']
y = data['BETA COS (TETA)']

# Realizar el ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Calcular la recta de ajuste
linea_ajuste = slope * x + intercept

# Crear la gráfica
plt.figure(figsize=(8, 6))
plt.scatter(x, y, label='Datos')
plt.plot(x, linea_ajuste, 'r', label='Ajuste Lineal')

# Limitar el rango en el eje Y
plt.ylim(0.006, 0.012)


# Mostrar la ecuación del ajuste en la gráfica
ecuacion_ajuste = f'Ecuación del ajuste: y = {slope:.5f}x + {intercept:.5f}\nR-cuadrado: {r_value**2:.2f}'
plt.text(0.5, 0.5, ecuacion_ajuste, fontsize=12, ha='left', va='center', transform=plt.gca().transAxes)

# Configuraciones adicionales
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico con Ajuste Lineal')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Realizar el ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Limitar el rango en el eje Y
y_min, y_max = 0.008, 0.016
x_range = np.linspace(min(x), max(x), 100)
linea_ajuste = slope * x_range + intercept

# Filtrar la línea de ajuste dentro del rango en el eje Y
x_range_filtered = x_range[(linea_ajuste >= y_min) & (linea_ajuste <= y_max)]
linea_ajuste_filtered = linea_ajuste[(linea_ajuste >= y_min) & (linea_ajuste <= y_max)]

# Crear la gráfica
plt.figure(figsize=(8, 6))
plt.scatter(x, y, label='Datos')
plt.plot(x_range_filtered, linea_ajuste_filtered, 'r', label='Ajuste Lineal')

# Limitar el rango en el eje Y
plt.ylim(y_min, y_max)

# Mostrar la ecuación del ajuste en la gráfica
ecuacion_ajuste = f'Ecuación del ajuste: y = {slope:.2f}x + {intercept:.2f}\nR-cuadrado: {r_value**2:.2f}'
plt.text(0.5, 0.9, ecuacion_ajuste, fontsize=12, ha='center', va='center', transform=plt.gca().transAxes)

# Configuraciones adicionales
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Gráfico con Ajuste Lineal')
plt.legend()
plt.grid(True)
plt.show()
