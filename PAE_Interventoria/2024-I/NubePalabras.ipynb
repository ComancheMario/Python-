# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize, pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\madro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\madro\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\madro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Llamar el archivo

df = pd.read_csv('Datos/Resultados .csv', delimiter=';', encoding='latin-1')

#Se filtran las que no cumple
df_filtrado = df[df['Respuesta']=='No cumple']

# %%
#Stop word en español
stop_words = set(stopwords.words('spanish'))
#Extraer sustantivos
def extraer_sustantivos(texto):
    tokens = nltk.word_tokenize(texto.lower())
    tags = nltk.pos_tag(tokens)
    sustantivos = [word for word, pos in tags if pos in ['NN','NNS','NNP','NNPS']  and word not in stop_words]
    return ' '.join(sustantivos)

df_filtrado['Sustantivos'] = df_filtrado['Observación'].apply(extraer_sustantivos)

df_filtrado
# Out:
# C:\Users\madro\AppData\Local\Temp\ipykernel_23100\1926686459.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Sustantivos'] = df_filtrado['Observación'].apply(extraer_sustantivos)
#               Código  N° Visita  N° Visita Total Fecha Planeada Inicio  \
# 250    IE-071-240527        1.0              1.0              27/05/24
# 253    IE-071-240527        1.0              1.0              27/05/24
# 256    IE-071-240527        1.0              1.0              27/05/24
# 269    IE-071-240527        1.0              1.0              27/05/24
# 277    IE-071-240527        1.0              1.0              27/05/24
# ...              ...        ...              ...                   ...
# 28172  IE-149-240813        2.0              2.0              13/08/24
# 28182  IE-149-240813        2.0              2.0              13/08/24
# 28501  IE-180-240813        2.0              2.0              13/08/24
# 28502  IE-180-240813        2.0              2.0              13/08/24
# 28504  IE-180-240813        2.0              2.0              13/08/24
#
#       Fecha Actualización         Municipio    Código IED  \
# 250              11/06/24  PALMAR DE VARELA  1.085200e+11
# 253              11/06/24  PALMAR DE VARELA  1.085200e+11
# 256              11/06/24  PALMAR DE VARELA  1.085200e+11
# 269              11/06/24  PALMAR DE VARELA  1.085200e+11
# 277              11/06/24  PALMAR DE VARELA  1.085200e+11
# ...                   ...               ...           ...
# 28172            14/08/24       SABANALARGA  2.086380e+11
# 28182            14/08/24       SABANALARGA  2.086380e+11
# 28501            13/08/24            TUBARA  2.088320e+11
# 28502            13/08/24            TUBARA  2.088320e+11
# 28504            13/08/24            TUBARA  2.088320e+11
#
#                                       Nombre IED   Código Sede  \
# 250    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# 253    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# 256    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# 269    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# 277    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# ...                                          ...           ...
# 28172   INSTITUCION EDUCATIVA TECNICO DE LA PE¿A  2.086380e+13
# 28182   INSTITUCION EDUCATIVA TECNICO DE LA PE¿A  2.086380e+13
# 28501        INSTITUCION EDUCATIVA PLAYA MENDOZA  2.088320e+13
# 28502        INSTITUCION EDUCATIVA PLAYA MENDOZA  2.088320e+13
# 28504        INSTITUCION EDUCATIVA PLAYA MENDOZA  2.088320e+13
#
#                                              Nombre Sede  Item  \
# 250    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   240
# 253    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   270
# 256    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   310
# 269    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   450
# 277    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   540
# ...                                                  ...   ...
# 28172                                         SEDE NO. 2   430
# 28182                                         SEDE NO. 2   540
# 28501                                 CORRAL DE SAN LUIS   240
# 28502                                 CORRAL DE SAN LUIS   250
# 28504                                 CORRAL DE SAN LUIS   270
#
#             Instrumento                                           Pregunta  \
# 250    Institución - RI  Existe botiquín de primeros auxilios que cumpl...
# 253    Institución - RI  Las ventanas y aberturas que se comuniquen con...
# 256    Institución - RI  Los espacios (paredes, pisos y techos) de las ...
# 269    Institución - RI  El almacenamiento de los alimentos refrigerado...
# 277    Institución - RI  Para los equipos que el operador recibio de la...
# ...                 ...                                                ...
# 28172  Institución - RI  El almacenamiento de los insumos, materias pri...
# 28182  Institución - RI  Para los equipos que el operador recibio de la...
# 28501  Institución - RI  Existe botiquín de primeros auxilios que cumpl...
# 28502  Institución - RI  Las lámparas o iluminación se encuentran prote...
# 28504  Institución - RI  Las ventanas y aberturas que se comuniquen con...
#
#        Respuesta                                        Observación  \
# 250    No cumple                    Dotación de botiquín incompleta
# 253    No cumple     Ventanas sin malla de protección anti insectos
# 256    No cumple          Techos con telarañas y paredes sin pintar
# 269    No cumple             No cuentan con equipo de refrigeración
# 277    No cumple  No cuentan con equipo de refrigeración.\nNo se...
# ...          ...                                                ...
# 28172  No cumple  las leches galletas y demas alimentos se conse...
# 28182  No cumple                   no se evidencia acta de entrega.
# 28501  No cumple            No existe botiquin de primeros auxilios
# 28502  No cumple                             No funcionan las luces
# 28504  No cumple  Las ventanas y aberturas que se comunican con ...
#
#        Actualizado Por               Estado  \
# 250    JULIRODRIGUEZPZ             Validado
# 253    JULIRODRIGUEZPZ             Validado
# 256    JULIRODRIGUEZPZ             Validado
# 269    JULIRODRIGUEZPZ             Validado
# 277    JULIRODRIGUEZPZ             Validado
# ...                ...                  ...
# 28172          RSOLANO  Instrumento cargado
# 28182          RSOLANO  Instrumento cargado
# 28501          MMONICA         Diligenciado
# 28502          MMONICA         Diligenciado
# 28504          MMONICA         Diligenciado
#
#                                   Obligación Contractual  \
# 250    Clausula 8. Obligaciones especificas del contr...
# 253    Clausula 8. Obligaciones especificas del contr...
# 256    Clausula 8. Obligaciones especificas del contr...
# 269    Clausula 8. Obligaciones especificas del contr...
# 277    Clausula 8. Obligaciones especificas del contr...
# ...                                                  ...
# 28172                                                NaN
# 28182                                                NaN
# 28501  Clausula 8. Obligaciones especificas del contr...
# 28502  Clausula 8. Obligaciones especificas del contr...
# 28504  Clausula 8. Obligaciones especificas del contr...
#
#                                              Sustantivos
# 250                                  dotación incompleta
# 253                         ventanas malla anti insectos
# 256                             telarañas paredes pintar
# 269                                 equipo refrigeración
# 277                                         equipo actas
# ...                                                  ...
# 28172  leches demas alimentos conservan embalaje mesa...
# 28182
# 28501                           existe botiquin auxilios
# 28502                                    funcionan luces
# 28504              ventanas provistas malla anti insecto
#
# [1977 rows x 19 columns]

# %%
#Se filtra todo lo que no es sustantivo y se elimina
#se crea la funcion

def filtrar_no_sustantivo(texto):
    try:
        #se toqueniza el texto en palabras
        palabra = nltk.word_tokenize(texto)
        
        #se generan las etiquetas gramaticales para las palabras
        palabras_etiquetadas = nltk.pos_tag(palabra)
        
        #Se filtra el sustantivo
        sustantivos = [palabra for palabra, etiqueta in palabras_etiquetadas if etiqueta.startswith('NN')]
        
        return ' '.join(sustantivos) if sustantivos else ''
    
    except Exception as e:
        print(f"Erro al procesar texto: {texto}")
        print(e)
        return ''
    
#se aplica la funcion a 'Observacion'

df_filtrado['Observaciones_Sustantivos'] = df_filtrado['Observación'].apply(lambda x: filtrar_no_sustantivo(str(x)))
df_filtrado['Observaciones_Sustantivos'] = df_filtrado['Observaciones_Sustantivos'].apply(lambda x: filtrar_no_sustantivo(str(x)))

df_filtrado
# Out:
# C:\Users\madro\AppData\Local\Temp\ipykernel_23100\1661950250.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Observaciones_Sustantivos'] = df_filtrado['Observación'].apply(lambda x: filtrar_no_sustantivo(str(x)))
# C:\Users\madro\AppData\Local\Temp\ipykernel_23100\1661950250.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['Observaciones_Sustantivos'] = df_filtrado['Observaciones_Sustantivos'].apply(lambda x: filtrar_no_sustantivo(str(x)))
#               Código  N° Visita  N° Visita Total Fecha Planeada Inicio  \
# 250    IE-071-240527        1.0              1.0              27/05/24
# 253    IE-071-240527        1.0              1.0              27/05/24
# 256    IE-071-240527        1.0              1.0              27/05/24
# 269    IE-071-240527        1.0              1.0              27/05/24
# 277    IE-071-240527        1.0              1.0              27/05/24
# ...              ...        ...              ...                   ...
# 28172  IE-149-240813        2.0              2.0              13/08/24
# 28182  IE-149-240813        2.0              2.0              13/08/24
# 28501  IE-180-240813        2.0              2.0              13/08/24
# 28502  IE-180-240813        2.0              2.0              13/08/24
# 28504  IE-180-240813        2.0              2.0              13/08/24
#
#       Fecha Actualización         Municipio    Código IED  \
# 250              11/06/24  PALMAR DE VARELA  1.085200e+11
# 253              11/06/24  PALMAR DE VARELA  1.085200e+11
# 256              11/06/24  PALMAR DE VARELA  1.085200e+11
# 269              11/06/24  PALMAR DE VARELA  1.085200e+11
# 277              11/06/24  PALMAR DE VARELA  1.085200e+11
# ...                   ...               ...           ...
# 28172            14/08/24       SABANALARGA  2.086380e+11
# 28182            14/08/24       SABANALARGA  2.086380e+11
# 28501            13/08/24            TUBARA  2.088320e+11
# 28502            13/08/24            TUBARA  2.088320e+11
# 28504            13/08/24            TUBARA  2.088320e+11
#
#                                       Nombre IED   Código Sede  \
# 250    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# 253    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# 256    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# 269    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# 277    INSTITUCION EDUCATIVA COMERCIAL DE PALMAR  1.085200e+13
# ...                                          ...           ...
# 28172   INSTITUCION EDUCATIVA TECNICO DE LA PE¿A  2.086380e+13
# 28182   INSTITUCION EDUCATIVA TECNICO DE LA PE¿A  2.086380e+13
# 28501        INSTITUCION EDUCATIVA PLAYA MENDOZA  2.088320e+13
# 28502        INSTITUCION EDUCATIVA PLAYA MENDOZA  2.088320e+13
# 28504        INSTITUCION EDUCATIVA PLAYA MENDOZA  2.088320e+13
#
#                                              Nombre Sede  Item  \
# 250    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   240
# 253    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   270
# 256    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   310
# 269    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   450
# 277    INSTITUCION EDUCATIVA TECNICA COMERCIAL DE PALMAR   540
# ...                                                  ...   ...
# 28172                                         SEDE NO. 2   430
# 28182                                         SEDE NO. 2   540
# 28501                                 CORRAL DE SAN LUIS   240
# 28502                                 CORRAL DE SAN LUIS   250
# 28504                                 CORRAL DE SAN LUIS   270
#
#             Instrumento                                           Pregunta  \
# 250    Institución - RI  Existe botiquín de primeros auxilios que cumpl...
# 253    Institución - RI  Las ventanas y aberturas que se comuniquen con...
# 256    Institución - RI  Los espacios (paredes, pisos y techos) de las ...
# 269    Institución - RI  El almacenamiento de los alimentos refrigerado...
# 277    Institución - RI  Para los equipos que el operador recibio de la...
# ...                 ...                                                ...
# 28172  Institución - RI  El almacenamiento de los insumos, materias pri...
# 28182  Institución - RI  Para los equipos que el operador recibio de la...
# 28501  Institución - RI  Existe botiquín de primeros auxilios que cumpl...
# 28502  Institución - RI  Las lámparas o iluminación se encuentran prote...
# 28504  Institución - RI  Las ventanas y aberturas que se comuniquen con...
#
#        Respuesta                                        Observación  \
# 250    No cumple                    Dotación de botiquín incompleta
# 253    No cumple     Ventanas sin malla de protección anti insectos
# 256    No cumple          Techos con telarañas y paredes sin pintar
# 269    No cumple             No cuentan con equipo de refrigeración
# 277    No cumple  No cuentan con equipo de refrigeración.\nNo se...
# ...          ...                                                ...
# 28172  No cumple  las leches galletas y demas alimentos se conse...
# 28182  No cumple                   no se evidencia acta de entrega.
# 28501  No cumple            No existe botiquin de primeros auxilios
# 28502  No cumple                             No funcionan las luces
# 28504  No cumple  Las ventanas y aberturas que se comunican con ...
#
#        Actualizado Por               Estado  \
# 250    JULIRODRIGUEZPZ             Validado
# 253    JULIRODRIGUEZPZ             Validado
# 256    JULIRODRIGUEZPZ             Validado
# 269    JULIRODRIGUEZPZ             Validado
# 277    JULIRODRIGUEZPZ             Validado
# ...                ...                  ...
# 28172          RSOLANO  Instrumento cargado
# 28182          RSOLANO  Instrumento cargado
# 28501          MMONICA         Diligenciado
# 28502          MMONICA         Diligenciado
# 28504          MMONICA         Diligenciado
#
#                                   Obligación Contractual  \
# 250    Clausula 8. Obligaciones especificas del contr...
# 253    Clausula 8. Obligaciones especificas del contr...
# 256    Clausula 8. Obligaciones especificas del contr...
# 269    Clausula 8. Obligaciones especificas del contr...
# 277    Clausula 8. Obligaciones especificas del contr...
# ...                                                  ...
# 28172                                                NaN
# 28182                                                NaN
# 28501  Clausula 8. Obligaciones especificas del contr...
# 28502  Clausula 8. Obligaciones especificas del contr...
# 28504  Clausula 8. Obligaciones especificas del contr...
#
#                                              Sustantivos  \
# 250                                  dotación incompleta
# 253                         ventanas malla anti insectos
# 256                             telarañas paredes pintar
# 269                                 equipo refrigeración
# 277                                         equipo actas
# ...                                                  ...
# 28172  leches demas alimentos conservan embalaje mesa...
# 28182
# 28501                           existe botiquin auxilios
# 28502                                    funcionan luces
# 28504              ventanas provistas malla anti insecto
#
#                                Observaciones_Sustantivos
# 250                                  Dotación incompleta
# 253                     Ventanas sin malla anti insectos
# 256                Techos con telarañas y paredes pintar
# 269                             con equipo refrigeración
# 277                                     con equipo actas
# ...                                                  ...
# 28172  las alimentos su embalaje mesa estado donde se...
# 28182                                                 se
# 28501                           existe botiquin auxilios
# 28502                                    funcionan luces
# 28504              Las ventanas con el provistas insecto
#
# [1977 rows x 20 columns]

# %%
# Unir todos los sustantivos en un solo texto
texto_para_nube = ' '.join(df_filtrado['Observaciones_Sustantivos'])

# Imprimir una muestra del texto para verificar
print(texto_para_nube[:500])  # Muestra los primeros 500 caracteres
# Out:
# Dotación incompleta Ventanas sin malla anti insectos Techos con telarañas y paredes pintar con equipo refrigeración con equipo actas alrededores maleza El área cumple con las condiciones El tablero cuenta con tapa Las ventanas malla anti insecto Se area almacenamiento El área Algunos con la piso por la norma Algunos alimentos estan apilados y la capacidad estanterias Se encontraron productos con empaque rotos y su contenido regado Se producto con borrosa y poco Durante techo tenia goteras area p

# %% [markdown]
# # Codigo completo para ingresar en power query

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize, pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')


df = pd.DataFrame(dataset)
#Se filtran las que no cumple
df = df[df['Respuesta']=='No cumple']

#Stop word en español
stop_words = set(stopwords.words('spanish'))
#Extraer sustantivos
def extraer_sustantivos(texto):
    tokens = nltk.word_tokenize(texto.lower())
    tags = nltk.pos_tag(tokens)
    sustantivos = [word for word, pos in tags if pos in ['NN','NNS','NNP','NNPS']  and word not in stop_words]
    return ' '.join(sustantivos)

df_filtrado['Sustantivos'] = df_filtrado['Observación'].apply(extraer_sustantivos)

#df_filtrado

#Se filtra todo lo que no es sustantivo y se elimina
#se crea la funcion

def filtrar_no_sustantivo(texto):
    try:
        #se toqueniza el texto en palabras
        palabra = nltk.word_tokenize(texto)
        
        #se generan las etiquetas gramaticales para las palabras
        palabras_etiquetadas = nltk.pos_tag(palabra)
        
        #Se filtra el sustantivo
        sustantivos = [palabra for palabra, etiqueta in palabras_etiquetadas if etiqueta.startswith('NN')]
        
        return ' '.join(sustantivos) if sustantivos else ''
    
    except Exception as e:
        print(f"Erro al procesar texto: {texto}")
        print(e)
        return ''
    
#se aplica la funcion a 'Observacion'

df_filtrado['Observaciones_Sustantivos'] = df_filtrado['Observación'].apply(lambda x: filtrar_no_sustantivo(str(x)))
df_filtrado['Observaciones_Sustantivos'] = df_filtrado['Observaciones_Sustantivos'].apply(lambda x: filtrar_no_sustantivo(str(x)))

#df_filtrado
